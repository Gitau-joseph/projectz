# %%
import os
from src.app import create_app, db
from src.app import models

# make sure there’s no conflict
db_path = os.path.join("src", "app", "platform.db")
if os.path.exists(db_path):
    os.remove(db_path)  # remove any broken DB

app = create_app()

with app.app_context():
    db.create_all()
    print("✅ Tables created successfully!")
    print("📁 Database path:", os.path.abspath(db_path))
# Out:
# ✅ Tables created successfully!
# 📁 Database path: C:\Users\hp\Desktop\Gn Joe\src\app\platform.db

# %%
import sqlite3

conn = sqlite3.connect("src/app/platform.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
conn.close()
# Out:
# []

# %%
from src.app import create_app, db
from src.app.models import User, KYCLog

app = create_app()

with app.app_context():
    db.drop_all()     # drop if partially created
    db.create_all()   # create fresh tables
    print("✅ Tables created successfully!")
# Out:
# ✅ Tables created successfully!

# %%
import os
print(os.listdir("src/app"))
# Out:
# ['auth.py', 'config.py', 'models.py', 'routes.py', 'static', 'templates', '__init__.py', '__pycache__']

# %%
import sqlite3

conn = sqlite3.connect("src/app/platform.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
conn.close()
# Out:
# []

# %%
from src.app import create_app, db
from src.app.models import User, KYCLog

app = create_app()

with app.app_context():
    db.drop_all()
    db.create_all()
    print("✅ Database and tables created successfully!")
# Out:
# ✅ Database and tables created successfully!

# %%
import os
print(os.listdir("src/app"))
# Out:
# ['auth.py', 'config.py', 'models.py', 'routes.py', 'static', 'templates', '__init__.py', '__pycache__']

# %%
from src.app import create_app, db
from src.app.models import User, KYCLog
import os

app = create_app()

BASE_DIR = os.path.abspath(os.path.dirname("src/app/__init__.py"))
db_path = os.path.join("src", "app", "platform.db")

with app.app_context():
    print("Creating database at:", os.path.abspath(db_path))
    db.create_all()

print("Done ✅")

# Check if the file exists
print("Database exists:", os.path.exists(db_path))
# Out:
# Creating database at: C:\Users\hp\Desktop\Gn Joe\src\app\platform.db
# Done ✅
# Database exists: False

# %%
import os
from src.app import create_app, db

ABS_PATH = os.path.abspath("C:/Users/hp/Desktop/Gn Joe/src/app/platform.db")
print("Using DB path:", ABS_PATH)

app = create_app()
app.config["SQLALCHEMY_DATABASE_URI"] = f"sqlite:///{ABS_PATH}"

with app.app_context():
    db.create_all()
    print("✅ Database created successfully at:", ABS_PATH)
# Out:
# Using DB path: C:\Users\hp\Desktop\Gn Joe\src\app\platform.db
# ✅ Database created successfully at: C:\Users\hp\Desktop\Gn Joe\src\app\platform.db

# %%
from src.app import create_app, db
from src.app.models import User, KYCLog
import os

app = create_app()

with app.app_context():
    db.drop_all()
    db.create_all()
    print("✅ Tables created successfully!")

# Confirm if file exists
db_path = os.path.join("src", "app", "platform.db")
print("Database exists:", os.path.exists(db_path))
print("Absolute path:", os.path.abspath(db_path))
# Out:
# ✅ Tables created successfully!
# Database exists: False
# Absolute path: C:\Users\hp\Desktop\Gn Joe\src\app\platform.db

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\hp\Desktop\Gn Joe

# %%
from flask import Flask
from flask_sqlalchemy import SQLAlchemy
import os

app = Flask(__name__)

# Force DB path inside "C:\Users\hp\Desktop\Gn Joe"
DB_PATH = os.path.join(r"C:\Users\hp\Desktop\Gn Joe", "platform.db")

app.config["SQLALCHEMY_DATABASE_URI"] = f"sqlite:///{DB_PATH}"
app.config["SQLALCHEMY_TRACK_MODIFICATIONS"] = False

db = SQLAlchemy(app)

# Define a quick test model
class User(db.Model):
    id = db.Column(db.Integer, primary_key=True)
    username = db.Column(db.String(100))

# Create the database
with app.app_context():
    db.create_all()
    print("✅ Database created successfully at:", DB_PATH)
    print("Exists:", os.path.exists(DB_PATH))
# Out:
# ✅ Database created successfully at: C:\Users\hp\Desktop\Gn Joe\platform.db
# Exists: True
